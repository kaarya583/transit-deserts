# %% [markdown]
# # 06: Visualization
#
# Produce final visuals:
# - Interactive maps (folium, kepler.gl, or plotly)
# - Static charts for report (boxplots, bar charts)
# - Optional: lightweight Streamlit (build within notebook) or export HTML map
# - Save all figures/HTML to `outputs/`

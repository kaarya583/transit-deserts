# %% [markdown]
# # 07: Reporting and Brief
#
# Assemble deliverables:
# - Pull tables/figures from previous notebooks
# - Draft bullet points for policy brief
# - Summarize methods and key findings
# - Export final PDF/Markdown/LaTeX to `outputs/`

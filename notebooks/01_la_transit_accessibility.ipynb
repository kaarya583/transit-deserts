# %% [markdown]
# # LA transit accessibility
#
# This notebook mirrors `scripts/run_la_analysis.py`: load GTFS + jobs + ACS, compute jobs reachable within 30 minutes, flag transit deserts, run Moran’s I, and save figures to `outputs/figures/`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").is_dir():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from la_analysis import run_pipeline

gdf, moran, summary = run_pipeline()
summary

# %%
if moran:
    print(f"Moran's I = {moran['I']:.4f}, p ≈ {moran['p_sim']:.4f}")
